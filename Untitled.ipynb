# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex

# %%
import sys

# %%
# !{sys.executable} -m pip install llama-index
# Out:
# Collecting llama-index
#   Using cached llama_index-0.14.21-py3-none-any.whl.metadata (14 kB)
# Collecting llama-index-core<0.15.0,>=0.14.21 (from llama-index)
#   Using cached llama_index_core-0.14.21-py3-none-any.whl.metadata (2.6 kB)
# Collecting llama-index-embeddings-openai<0.7,>=0.6.0 (from llama-index)
#   Using cached llama_index_embeddings_openai-0.6.0-py3-none-any.whl.metadata (401 bytes)
# Collecting llama-index-llms-openai<0.8,>=0.7.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.7.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting nltk>=3.9.3 (from llama-index)
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (3.13.5)
# Requirement already satisfied: aiosqlite in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.21.0)
# Collecting banks<3,>=2.3.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Downloading banks-2.4.2-py3-none-any.whl.metadata (12 kB)
# Collecting dataclasses-json (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting dirtyjson<2,>=1.0.8 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2,>=1.2.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2026.3.0)
# Requirement already satisfied: httpx in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.28.1)
# Collecting llama-index-workflows<3,>=2.14.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached llama_index_workflows-2.20.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (3.6.1)
# Requirement already satisfied: numpy in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.4.4)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (12.2.0)
# Requirement already satisfied: platformdirs in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.9.6)
# Requirement already satisfied: pydantic>=2.8.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.11.10)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.33.1)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (81.0.0)
# Collecting sqlalchemy>=1.4.49 (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (9.1.4)
# Collecting tiktoken>=0.7.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting tinytag>=2.2.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached tinytag-2.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.15.0)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.23.0)
# Collecting griffe (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached griffe-2.0.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (2.32.0)
# Collecting llama-index-instrumentation>=0.4.3 (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached llama_index_instrumentation-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (0.13.0)
# Requirement already satisfied: sniffio in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (3.11)
# Requirement already satisfied: certifi in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.6)
# Requirement already satisfied: click in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9.3->llama-index) (8.1.8)
# Requirement already satisfied: joblib in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9.3->llama-index) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9.3->llama-index) (2026.1.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.6.3)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging>=17.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.21->llama-index) (26.1)
# Collecting griffecli==2.0.2 (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached griffecli-2.0.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting griffelib==2.0.2 (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index)
#   Using cached griffelib-2.0.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.0.3)
# Using cached llama_index-0.14.21-py3-none-any.whl (7.1 kB)
# Using cached llama_index_core-0.14.21-py3-none-any.whl (11.9 MB)
# Downloading banks-2.4.2-py3-none-any.whl (35 kB)
# Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached llama_index_embeddings_openai-0.6.0-py3-none-any.whl (7.7 kB)
# Downloading llama_index_llms_openai-0.7.6-py3-none-any.whl (28 kB)
# Using cached llama_index_workflows-2.20.0-py3-none-any.whl (121 kB)
# Using cached deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Using cached llama_index_instrumentation-0.5.0-py3-none-any.whl (16 kB)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl (2.1 MB)
# Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl (238 kB)
# Using cached tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
# Using cached tinytag-2.2.1-py3-none-any.whl (32 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached griffe-2.0.2-py3-none-any.whl (5.1 kB)
# Using cached griffecli-2.0.2-py3-none-any.whl (9.5 kB)
# Using cached griffelib-2.0.2-py3-none-any.whl (142 kB)
# Installing collected packages: filetype, dirtyjson, tinytag, mypy-extensions, marshmallow, griffelib, greenlet, deprecated, typing-inspect, tiktoken, sqlalchemy, nltk, griffecli, llama-index-instrumentation, griffe, dataclasses-json, llama-index-workflows, banks, llama-index-core, llama-index-llms-openai, llama-index-embeddings-openai, llama-index
#
#    ----------------------------------------  0/22 [filetype]
#    - --------------------------------------  1/22 [dirtyjson]
#    --- ------------------------------------  2/22 [tinytag]
#    ------- --------------------------------  4/22 [marshmallow]
#    --------- ------------------------------  5/22 [griffelib]
#    --------- ------------------------------  5/22 [griffelib]
#    --------- ------------------------------  5/22 [griffelib]
#    --------- ------------------------------  5/22 [griffelib]
#    --------- ------------------------------  5/22 [griffelib]
#    ---------- -----------------------------  6/22 [greenlet]
#    ---------- -----------------------------  6/22 [greenlet]
#    ---------- -----------------------------  6/22 [greenlet]
#    -------------- -------------------------  8/22 [typing-inspect]
#    ---------------- -----------------------  9/22 [tiktoken]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    ------------------ --------------------- 10/22 [sqlalchemy]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    -------------------- ------------------- 11/22 [nltk]
#    --------------------- ------------------ 12/22 [griffecli]
#    ----------------------- ---------------- 13/22 [llama-index-instrumentation]
#    --------------------------- ------------ 15/22 [dataclasses-json]
#    ----------------------------- ---------- 16/22 [llama-index-workflows]
#    ----------------------------- ---------- 16/22 [llama-index-workflows]
#    ----------------------------- ---------- 16/22 [llama-index-workflows]
#    ----------------------------- ---------- 16/22 [llama-index-workflows]
#    ------------------------------ --------- 17/22 [banks]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    -------------------------------- ------- 18/22 [llama-index-core]
#    ---------------------------------- ----- 19/22 [llama-index-llms-openai]
#    ---------------------------------- --- 20/22 [llama-index-embeddings-openai]
#    ---------------------------------------- 22/22 [llama-index]
#
# Successfully installed banks-2.4.2 dataclasses-json-0.6.7 deprecated-1.3.1 dirtyjson-1.0.8 filetype-1.2.0 greenlet-3.5.0 griffe-2.0.2 griffecli-2.0.2 griffelib-2.0.2 llama-index-0.14.21 llama-index-core-0.14.21 llama-index-embeddings-openai-0.6.0 llama-index-instrumentation-0.5.0 llama-index-llms-openai-0.7.6 llama-index-workflows-2.20.0 marshmallow-3.26.2 mypy-extensions-1.1.0 nltk-3.9.4 sqlalchemy-2.0.49 tiktoken-0.12.0 tinytag-2.2.1 typing-inspect-0.9.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/82/c0/7e4fcd14dc8e7a47a8f16df33882f4cede3a526fd9d6af6d793c18188964/llama_index_llms_openai-0.7.6-py3-none-any.whl.metadata

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex

# %%
import os
os.makedirs("data", exist_ok=True)
with open("data/sample.txt", "w") as f:
    f.write("Artificial Intelligence is transforming the world. Machine Learning is a subset of AI.")

# %%
documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\embeddings\utils.py:58, in resolve_embed_model(embed_model, callback_manager)
#      57     embed_model = OpenAIEmbedding()
# ---> 58     validate_openai_api_key(embed_model.api_key)  # type: ignore
#      59 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\embeddings\openai\utils.py:157, in validate_openai_api_key(api_key)
#     156 if not openai_api_key:
# --> 157     raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 documents = SimpleDirectoryReader("data").load_data()
# ----> 2 index = VectorStoreIndex.from_documents(documents)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\indices\base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.id_, doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\indices\vector_store\base.py:71, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      68 self._use_async = use_async
#      69 self._store_nodes_override = store_nodes_override
#      70 self._embed_model = resolve_embed_model(
# ---> 71     embed_model or Settings.embed_model, callback_manager=callback_manager
#      72 )
#      74 self._insert_batch_size = insert_batch_size
#      75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#    (...)     83     **kwargs,
#      84 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\settings.py:64, in _Settings.embed_model(self)
#      62 """Get the embedding model."""
#      63 if self._embed_model is None:
# ---> 64     self._embed_model = resolve_embed_model("default")
#      66 if self._callback_manager is not None:
#      67     self._embed_model.callback_manager = self._callback_manager
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\embeddings\utils.py:65, in resolve_embed_model(embed_model, callback_manager)
#      60         raise ImportError(
#      61             "`llama-index-embeddings-openai` package not found, "
#      62             "please run `pip install llama-index-embeddings-openai`"
#      63         )
#      64     except ValueError as e:
# ---> 65         raise ValueError(
#      66             "\n******\n"
#      67             "Could not load OpenAI embedding model. "
#      68             "If you intended to use OpenAI, please check your OPENAI_API_KEY.\n"
#      69             "Original error:\n"
#      70             f"{e!s}"
#      71             "\nConsider using embed_model='local'.\n"
#      72             "Visit our documentation for more embedding options: "
#      73             "https://developers.llamaindex.ai/python/framework/module_guides/"
#      74             "models/embeddings/"
#      75             "\n******"
#      76         )
#      77 # for image multi-modal embeddings
#      78 elif isinstance(embed_model, str) and embed_model.startswith("clip"):
#
# ValueError:
# ******
# Could not load OpenAI embedding model. If you intended to use OpenAI, please check your OPENAI_API_KEY.
# Original error:
# No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
# Consider using embed_model='local'.
# Visit our documentation for more embedding options: https://developers.llamaindex.ai/python/framework/module_guides/models/embeddings/
# ******

# %%
documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\embeddings\utils.py:58, in resolve_embed_model(embed_model, callback_manager)
#      57     embed_model = OpenAIEmbedding()
# ---> 58     validate_openai_api_key(embed_model.api_key)  # type: ignore
#      59 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\embeddings\openai\utils.py:157, in validate_openai_api_key(api_key)
#     156 if not openai_api_key:
# --> 157     raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 documents = SimpleDirectoryReader("data").load_data()
# ----> 2 index = VectorStoreIndex.from_documents(documents)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\indices\base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.id_, doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\indices\vector_store\base.py:71, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      68 self._use_async = use_async
#      69 self._store_nodes_override = store_nodes_override
#      70 self._embed_model = resolve_embed_model(
# ---> 71     embed_model or Settings.embed_model, callback_manager=callback_manager
#      72 )
#      74 self._insert_batch_size = insert_batch_size
#      75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#    (...)     83     **kwargs,
#      84 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\settings.py:64, in _Settings.embed_model(self)
#      62 """Get the embedding model."""
#      63 if self._embed_model is None:
# ---> 64     self._embed_model = resolve_embed_model("default")
#      66 if self._callback_manager is not None:
#      67     self._embed_model.callback_manager = self._callback_manager
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\embeddings\utils.py:65, in resolve_embed_model(embed_model, callback_manager)
#      60         raise ImportError(
#      61             "`llama-index-embeddings-openai` package not found, "
#      62             "please run `pip install llama-index-embeddings-openai`"
#      63         )
#      64     except ValueError as e:
# ---> 65         raise ValueError(
#      66             "\n******\n"
#      67             "Could not load OpenAI embedding model. "
#      68             "If you intended to use OpenAI, please check your OPENAI_API_KEY.\n"
#      69             "Original error:\n"
#      70             f"{e!s}"
#      71             "\nConsider using embed_model='local'.\n"
#      72             "Visit our documentation for more embedding options: "
#      73             "https://developers.llamaindex.ai/python/framework/module_guides/"
#      74             "models/embeddings/"
#      75             "\n******"
#      76         )
#      77 # for image multi-modal embeddings
#      78 elif isinstance(embed_model, str) and embed_model.startswith("clip"):
#
# ValueError:
# ******
# Could not load OpenAI embedding model. If you intended to use OpenAI, please check your OPENAI_API_KEY.
# Original error:
# No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
# Consider using embed_model='local'.
# Visit our documentation for more embedding options: https://developers.llamaindex.ai/python/framework/module_guides/models/embeddings/
# ******
